# %% [markdown]
# <a href="https://colab.research.google.com/github/debsubdavis/hydropho-natics/blob/dd-one-minus/one_minus/model_training_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.0/716.0 kB 13.8 MB/s eta 0:00:00
# ...

# %%
#!pip install ultralytics
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 133MB/s]

# %%
#ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-iter-2.v3i.yolov8 (1)"

ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-one-az.v3-minus-iter-3-nomiw.yolov8"
output = "/content/drive/MyDrive/capstone_data/minus-one-az.v3-minus-iter-3-nomiw.yolov8/results"

# %% [markdown]
# ***Testing using hyperparameters from best run on MINUS iter2 and ONE iter1***

# %%
# batch=16
# optimizer=”Adam”
# lr0=0.01
# iou=0.3
# dropout=0.2
# epochs=200
# patience=50


results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.3,
                      optimizer="Adam",
                      name="best-hyperparameters-from-minus-iter2",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
ROOT_DIR_ONE = "/content/drive/MyDrive/capstone_data/minus-one-az.v4-one-iter-2-ke.yolov8"
output_ONE = "/content/drive/MyDrive/capstone_data/minus-one-az.v4-one-iter-2-ke.yolov8/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_ONE, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.3,
                      optimizer="Adam",
                      name="best-hyperparameters-from-one-iter1",
                      pretrained="/content/drive/MyDrive/capstone_data/one-iter-1/best.pt",
                      project=output_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# Combined - MINUS

# %%
ROOT_DIR_combined = "/content/drive/MyDrive/capstone_data/combined"
output_combined = "/content/drive/MyDrive/capstone_data/combined/results"

results = model.train(data=os.path.join(ROOT_DIR_combined, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=0,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.3,
                      optimizer="Adam",
                      name="combined-best-hyperparameters-from-minus-iter2",
                      pretrained="yolov8m.pt",
                      project=output_combined)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# Combined - ONE

# %%
ROOT_DIR_combined_ONE = "/content/drive/MyDrive/capstone_data/combined_one"
output_combined_ONE = "/content/drive/MyDrive/capstone_data/combined_one/results"

results = model.train(data=os.path.join(ROOT_DIR_combined_ONE, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.3,
                      optimizer="Adam",
                      name="combined_ONE-best-hyperparameters-from-one-iter1",
                      pretrained="yolov8m.pt",
                      project=output_combined_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# ***Testing based on hyperparameter tuning google sheet***

# %%
#minus-iter3-batch8-lr.001
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"),
                      batch=8,
                      epochs=200,
                      patience=50,
                      lr0=0.001,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=50,
                      lr0=0.001,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"),
                      batch=32,
                      epochs=200,
                      patience=50,
                      lr0=0.001,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"),
                      batch=32,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="batch32-lr.01-v1",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="batch16-lr.01",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"),
                      batch=8,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="batch8-lr.01",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ONE MODEL
# pretrained = best.pt from Fred Olsen hyperparameter tuning

# %%
#ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-iter-2.v3i.yolov8 (1)"

ROOT_DIR_ONE = "/content/drive/MyDrive/capstone_data/minus-one-az.v4-one-iter-2-ke.yolov8"
output_ONE = "/content/drive/MyDrive/capstone_data/minus-one-az.v4-one-iter-2-ke.yolov8/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_ONE, "data.yaml"),
                      batch=8,
                      epochs=200,
                      patience=100,
                      lr0=0.001,
                      dropout=0.2,
                      optimizer="SGD",
                      name="one-batch8-lr.001-v1",
                      pretrained="/content/drive/MyDrive/capstone_data/one-iter-1/best.pt",
                      project=output_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR_ONE, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=50,
                      lr0=0.001,
                      dropout=0.2,
                      iou=0.2,
                      optimizer="SGD",
                      name="one-batch16-lr.001",
                      pretrained="/content/drive/MyDrive/capstone_data/one-iter-1/best.pt",
                      project=output_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR_ONE, "data.yaml"),
                      batch=32,
                      epochs=200,
                      patience=50,
                      lr0=0.001,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="one-batch32-lr.001",
                      pretrained="/content/drive/MyDrive/capstone_data/one-iter-1/best.pt",
                      project=output_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR_ONE, "data.yaml"),
                      batch=8,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="one-batch8-lr.01",
                      pretrained="/content/drive/MyDrive/capstone_data/one-iter-1/best.pt",
                      project=output_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR_ONE, "data.yaml"),
                      batch=16,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="one-batch16-lr.01",
                      pretrained="/content/drive/MyDrive/capstone_data/one-iter-1/best.pt",
                      project=output_ONE)

# %%
results = model.train(data=os.path.join(ROOT_DIR_ONE, "data.yaml"),
                      batch=32,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="one-batch32-lr.01",
                      pretrained="/content/drive/MyDrive/capstone_data/one-iter-1/best.pt",
                      project=output_ONE)

# %% [markdown]
# COMBINED
# - Combined Fred Olsen and Azura images in order to train on them at the same time. Instead of training on Fred Olsen, then using the best weights from Fred Olsen as the starting point for training Azura

# %%
#ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-iter-2.v3i.yolov8 (1)"

ROOT_DIR_combined = "/content/drive/MyDrive/capstone_data/combined"
output_combined = "/content/drive/MyDrive/capstone_data/combined/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_combined, "data.yaml"),
                      batch=32,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="combined-batch32-lr.01",
                      pretrained="yolov8m.pt",
                      project=output_combined)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# COMBINED_ONE

# %%
#ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-iter-2.v3i.yolov8 (1)"

ROOT_DIR_combined_ONE = "/content/drive/MyDrive/capstone_data/combined_one"
output_combined_ONE = "/content/drive/MyDrive/capstone_data/combined_one/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_combined_ONE, "data.yaml"),
                      batch=32,
                      epochs=500,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="combined_ONE-500epochs-batch32-lr.01",
                      pretrained="yolov8m.pt",
                      project=output_combined_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR_combined_ONE, "data.yaml"),
                      batch=32,
                      epochs=200,
                      patience=50,
                      lr0=0.01,
                      dropout=0.2,
                      iou=0.5,
                      optimizer="SGD",
                      name="combined_ONE-batch32-lr.01",
                      pretrained="yolov8m.pt",
                      project=output_combined_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
results = model.train(data=os.path.join(ROOT_DIR_combined_ONE, "data.yaml"),
                      epochs=500,
                      patience=100,
                      name="combined_ONE-default",
                      pretrained="yolov8m.pt",
                      project=output_combined_ONE)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# TESTNG CROPPED IMAGES (MINUS) FOR AZURA
# trial_1: start with yolom.pt
# trial_2: start with best.pt from MINUS hyperparamater tuning on Fred Olsen

# %% [markdown]
# **BASELINE: Minus-iter3 without any changes (mooring, interesting, wec removed in roboflow)**

# %%
#ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-iter-2.v3i.yolov8 (1)"

ROOT_DIR_minus_iter3 = "/content/drive/MyDrive/capstone_data/minus-one-az.v3-minus-iter-3-nomiw.yolov8"
output_minus_iter3 = "/content/drive/MyDrive/capstone_data/minus-one-az.v3-minus-iter-3-nomiw.yolov8/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_minus_iter3, "data.yaml"),
                      # batch=32,
                      epochs=200,
                      #patience=50,
                      # lr0=0.01,
                      # dropout=0.2,
                      # iou=0.5,
                      # optimizer="SGD",
                      name="minus-iter3-baseline",
                      pretrained="yolov8m.pt",
                      project=output_minus_iter3)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# **Testing cropped images for minus iter 3 (mooring, interesting, wec removed**

# %%
#ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-iter-2.v3i.yolov8 (1)"

ROOT_DIR_cropped = "/content/drive/MyDrive/capstone_data/minus-one-az.v6-cropped-minus-iter-3-v2-nomiw.yolov8"
output_cropped = "/content/drive/MyDrive/capstone_data/minus-one-az.v6-cropped-minus-iter-3-v2-nomiw.yolov8/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_cropped, "data.yaml"),
                      # batch=32,
                      epochs=200,
                      patience=50,
                      # lr0=0.01,
                      # dropout=0.2,
                      # iou=0.5,
                      # optimizer="SGD",
                      name="cropped-test",
                      pretrained="yolov8m.pt",
                      project=output_cropped)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# **Still testing cropped for minus-iter-3, used best.pt for minus-iter-2 as the starting model**

# %%
results = model.train(data=os.path.join(ROOT_DIR_cropped, "data.yaml"),
                      # batch=32,
                      epochs=200,
                      patience=50,
                      # lr0=0.01,
                      # dropout=0.2,
                      # iou=0.5,
                      # optimizer="SGD",
                      name="cropped-test-bestITER2",
                      pretrained="/content/drive/MyDrive/capstone_data/minus-iter2-WITHOUT-mooring/best.pt",
                      project=output_cropped)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# **Testing using crop for ONE iter 2 (Azura data)**

# %%
#ROOT_DIR = "/content/drive/MyDrive/capstone_data/minus-iter-2.v3i.yolov8 (1)"

ROOT_DIR_cropped_one = "/content/drive/MyDrive/capstone_data/minus-one-az.v10-cropped-one-iter2.yolov8 (1)"
output_cropped_one = "/content/drive/MyDrive/capstone_data/minus-one-az.v10-cropped-one-iter2.yolov8 (1)"

# %%
results = model.train(data=os.path.join(ROOT_DIR_cropped_one, "data.yaml"),
                      # batch=32,
                      epochs=200,
                      patience=100,
                      # lr0=0.01,
                      # dropout=0.2,
                      # iou=0.5,
                      # optimizer="SGD",
                      name="cropped-ONE-test",
                      pretrained="yolov8m.pt",
                      project=output_cropped)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# **Testing cropped and creating 2 different sound categories for the ONE model (one-iter-2) for Azura dataset**

# %% [markdown]
# *2 categories:*
#
# *   *Sound 1: everything else*
# *   *Sound 2: humpback + mooring*

# %%
ROOT_DIR_cropped_one_2cats = "/content/drive/MyDrive/capstone_data/minus-one-az.v7-cropped-one-iter2-2categ.yolov8"
output_cropped_one_2cats = "/content/drive/MyDrive/capstone_data/minus-one-az.v7-cropped-one-iter2-2categ.yolov8/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_cropped_one_2cats, "data.yaml"),
                      # batch=32,
                      epochs=200,
                      patience=50,
                      # lr0=0.01,
                      # dropout=0.2,
                      # iou=0.5,
                      # optimizer="SGD",
                      name="cropped-ONE-2cats-test",
                      pretrained="yolov8m.pt",
                      project=output_cropped_one_2cats)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# ***2 categories (not cropped)***

# %%
ROOT_DIR_one_2cats = "/content/drive/MyDrive/capstone_data/minus-one-az.v8-one-iter2-2categ.yolov8"
output_one_2cats = "/content/drive/MyDrive/capstone_data/minus-one-az.v8-one-iter2-2categ.yolov8/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_one_2cats, "data.yaml"),
                      # batch=32,
                      epochs=200,
                      patience=50,
                      # lr0=0.01,
                      # dropout=0.2,
                      # iou=0.5,
                      # optimizer="SGD",
                      name="ONE-2cats-test",
                      pretrained="yolov8m.pt",
                      project=output_one_2cats)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# **Testing using Cropped and resized images for MINUS Iter 3 (Azura dataset)**

# %%
ROOT_DIR_minus_iter3_crop_resize = "/content/drive/MyDrive/capstone_data/minus-one-az.v8-one-iter2-2categ.yolov8"
output_minus_iter3_crop_resize = "/content/drive/MyDrive/capstone_data/minus-one-az.v8-one-iter2-2categ.yolov8/results"

# %%
results = model.train(data=os.path.join(ROOT_DIR_minus_iter3_crop_resize, "data.yaml"),
                      # batch=32,
                      epochs=200,
                      patience=50,
                      # lr0=0.01,
                      # dropout=0.2,
                      # iou=0.5,
                      # optimizer="SGD",
                      name="MINUS-iter3-crop-resize-test",
                      pretrained="yolov8m.pt",
                      project=output_minus_iter3_crop_resize)
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...
